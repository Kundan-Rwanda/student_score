# %%
import pandas as pd
import os
import random
import numpy as np

# Function to generate and write data in chunks
def generate_large_dataset(file_name, num_records, chunk_size=100000):
    columns = ["No", "Regno", "Names", "Assign1/10", "Assign2/10", "Practical/10", "MidTerm Exam/30", "Final Exam/40"]

    # Check if file exists to avoid rewriting the header
    file_exists = os.path.exists(file_name)
    
    with open(file_name, 'a') as f:  # Open in append mode
        if not file_exists:
            # Write header only if the file does not exist
            f.write(",".join(columns) + "\n")
        
        for chunk_start in range(1, num_records + 1, chunk_size):
            chunk_end = min(chunk_start + chunk_size, num_records + 1)
            data = []
            
            for i in range(chunk_start, chunk_end):
                regno = f"240{str(i).zfill(7)}"  # Ensure unique student registration numbers
                name = f"Student{i}"
                
                assign1 = random.choice([9, 8, 7]) if random.random() > 0.1 else ''
                assign2 = random.choice([9, 8, 7]) if random.random() > 0.1 else ''
                practical = random.choice([6, 5, 4]) if random.random() > 0.1 else ''
                midterm_exam = random.randint(10, 30) if random.random() > 0.1 else ''
                final_exam = random.randint(20, 40) if random.random() > 0.1 else ''
                
                data.append([i, regno, name, assign1, assign2, practical, midterm_exam, final_exam])
            
            # Convert to DataFrame and write in chunks to reduce memory usage
            df = pd.DataFrame(data, columns=columns)
            df.to_csv(f, mode='a', header=False, index=False)
            
            print(f"Written {chunk_end - 1} records so far...")
    
    print(f"Dataset '{file_name}' with {num_records} records generated successfully.")

# Set the number of records to generate (~15 million for ~1GB file)
num_records = 30000000  # Adjust as needed
file_name = "large_student_scores.csv"
generate_large_dataset(file_name, num_records)
# Out:
# Written 100000 records so far...
# Written 200000 records so far...
# Written 300000 records so far...
# Written 400000 records so far...
# Written 500000 records so far...
# Written 600000 records so far...
# Written 700000 records so far...
# Written 800000 records so far...
# Written 900000 records so far...
# Written 1000000 records so far...
# Written 1100000 records so far...
# Written 1200000 records so far...
# Written 1300000 records so far...
# Written 1400000 records so far...
# Written 1500000 records so far...
# Written 1600000 records so far...
# Written 1700000 records so far...
# Written 1800000 records so far...
# Written 1900000 records so far...
# Written 2000000 records so far...
# Written 2100000 records so far...
# Written 2200000 records so far...
# Written 2300000 records so far...
# Written 2400000 records so far...
# Written 2500000 records so far...
# Written 2600000 records so far...
# Written 2700000 records so far...
# Written 2800000 records so far...
# Written 2900000 records so far...
# Written 3000000 records so far...
# Written 3100000 records so far...
# Written 3200000 records so far...
# Written 3300000 records so far...
# Written 3400000 records so far...
# Written 3500000 records so far...
# Written 3600000 records so far...
# Written 3700000 records so far...
# Written 3800000 records so far...
# Written 3900000 records so far...
# Written 4000000 records so far...
# Written 4100000 records so far...
# Written 4200000 records so far...
# Written 4300000 records so far...
# Written 4400000 records so far...
# Written 4500000 records so far...
# Written 4600000 records so far...
# Written 4700000 records so far...
# Written 4800000 records so far...
# Written 4900000 records so far...
# Written 5000000 records so far...
# Written 5100000 records so far...
# Written 5200000 records so far...
# Written 5300000 records so far...
# Written 5400000 records so far...
# Written 5500000 records so far...
# Written 5600000 records so far...
# Written 5700000 records so far...
# Written 5800000 records so far...
# Written 5900000 records so far...
# Written 6000000 records so far...
# Written 6100000 records so far...
# Written 6200000 records so far...
# Written 6300000 records so far...
# Written 6400000 records so far...
# Written 6500000 records so far...
# Written 6600000 records so far...
# Written 6700000 records so far...
# Written 6800000 records so far...
# Written 6900000 records so far...
# Written 7000000 records so far...
# Written 7100000 records so far...
# Written 7200000 records so far...
# Written 7300000 records so far...
# Written 7400000 records so far...
# Written 7500000 records so far...
# Written 7600000 records so far...
# Written 7700000 records so far...
# Written 7800000 records so far...
# Written 7900000 records so far...
# Written 8000000 records so far...
# Written 8100000 records so far...
# Written 8200000 records so far...
# Written 8300000 records so far...
# Written 8400000 records so far...
# Written 8500000 records so far...
# Written 8600000 records so far...
# Written 8700000 records so far...
# Written 8800000 records so far...
# Written 8900000 records so far...
# Written 9000000 records so far...
# Written 9100000 records so far...
# Written 9200000 records so far...
# Written 9300000 records so far...
# Written 9400000 records so far...
# Written 9500000 records so far...
# Written 9600000 records so far...
# Written 9700000 records so far...
# Written 9800000 records so far...
# Written 9900000 records so far...
# Written 10000000 records so far...
# Written 10100000 records so far...
# Written 10200000 records so far...
# Written 10300000 records so far...
# Written 10400000 records so far...
# Written 10500000 records so far...
# Written 10600000 records so far...
# Written 10700000 records so far...
# Written 10800000 records so far...
# Written 10900000 records so far...
# Written 11000000 records so far...
# Written 11100000 records so far...
# Written 11200000 records so far...
# Written 11300000 records so far...
# Written 11400000 records so far...
# Written 11500000 records so far...
# Written 11600000 records so far...
# Written 11700000 records so far...
# Written 11800000 records so far...
# Written 11900000 records so far...
# Written 12000000 records so far...
# Written 12100000 records so far...
# Written 12200000 records so far...
# Written 12300000 records so far...
# Written 12400000 records so far...
# Written 12500000 records so far...
# Written 12600000 records so far...
# Written 12700000 records so far...
# Written 12800000 records so far...
# Written 12900000 records so far...
# Written 13000000 records so far...
# Written 13100000 records so far...
# Written 13200000 records so far...
# Written 13300000 records so far...
# Written 13400000 records so far...
# Written 13500000 records so far...
# Written 13600000 records so far...
# Written 13700000 records so far...
# Written 13800000 records so far...
# Written 13900000 records so far...
# Written 14000000 records so far...
# Written 14100000 records so far...
# Written 14200000 records so far...
# Written 14300000 records so far...
# Written 14400000 records so far...
# Written 14500000 records so far...
# Written 14600000 records so far...
# Written 14700000 records so far...
# Written 14800000 records so far...
# Written 14900000 records so far...
# Written 15000000 records so far...
# Written 15100000 records so far...
# Written 15200000 records so far...
# Written 15300000 records so far...
# Written 15400000 records so far...
# Written 15500000 records so far...
# Written 15600000 records so far...
# Written 15700000 records so far...
# Written 15800000 records so far...
# Written 15900000 records so far...
# Written 16000000 records so far...
# Written 16100000 records so far...
# Written 16200000 records so far...
# Written 16300000 records so far...
# Written 16400000 records so far...
# Written 16500000 records so far...
# Written 16600000 records so far...
# Written 16700000 records so far...
# Written 16800000 records so far...
# Written 16900000 records so far...
# Written 17000000 records so far...
# Written 17100000 records so far...
# Written 17200000 records so far...
# Written 17300000 records so far...
# Written 17400000 records so far...
# Written 17500000 records so far...
# Written 17600000 records so far...
# Written 17700000 records so far...
# Written 17800000 records so far...
# Written 17900000 records so far...
# Written 18000000 records so far...
# Written 18100000 records so far...
# Written 18200000 records so far...
# Written 18300000 records so far...
# Written 18400000 records so far...
# Written 18500000 records so far...
# Written 18600000 records so far...
# Written 18700000 records so far...
# Written 18800000 records so far...
# Written 18900000 records so far...
# Written 19000000 records so far...
# Written 19100000 records so far...
# Written 19200000 records so far...
# Written 19300000 records so far...
# Written 19400000 records so far...
# Written 19500000 records so far...
# Written 19600000 records so far...
# Written 19700000 records so far...
# Written 19800000 records so far...
# Written 19900000 records so far...
# Written 20000000 records so far...
# Written 20100000 records so far...
# Written 20200000 records so far...
# Written 20300000 records so far...
# Written 20400000 records so far...
# Written 20500000 records so far...
# Written 20600000 records so far...
# Written 20700000 records so far...
# Written 20800000 records so far...
# Written 20900000 records so far...
# Written 21000000 records so far...
# Written 21100000 records so far...
# Written 21200000 records so far...
# Written 21300000 records so far...
# Written 21400000 records so far...
# Written 21500000 records so far...
# Written 21600000 records so far...
# Written 21700000 records so far...
# Written 21800000 records so far...
# Written 21900000 records so far...
# Written 22000000 records so far...
# Written 22100000 records so far...
# Written 22200000 records so far...
# Written 22300000 records so far...
# Written 22400000 records so far...
# Written 22500000 records so far...
# Written 22600000 records so far...
# Written 22700000 records so far...
# Written 22800000 records so far...
# Written 22900000 records so far...
# Written 23000000 records so far...
# Written 23100000 records so far...
# Written 23200000 records so far...
# Written 23300000 records so far...
# Written 23400000 records so far...
# Written 23500000 records so far...
# Written 23600000 records so far...
# Written 23700000 records so far...
# Written 23800000 records so far...
# Written 23900000 records so far...
# Written 24000000 records so far...
# Written 24100000 records so far...
# Written 24200000 records so far...
# Written 24300000 records so far...
# Written 24400000 records so far...
# Written 24500000 records so far...
# Written 24600000 records so far...
# Written 24700000 records so far...
# Written 24800000 records so far...
# Written 24900000 records so far...
# Written 25000000 records so far...
# Written 25100000 records so far...
# Written 25200000 records so far...
# Written 25300000 records so far...
# Written 25400000 records so far...
# Written 25500000 records so far...
# Written 25600000 records so far...
# Written 25700000 records so far...
# Written 25800000 records so far...
# Written 25900000 records so far...
# Written 26000000 records so far...
# Written 26100000 records so far...
# Written 26200000 records so far...
# Written 26300000 records so far...
# Written 26400000 records so far...
# Written 26500000 records so far...
# Written 26600000 records so far...
# Written 26700000 records so far...
# Written 26800000 records so far...
# Written 26900000 records so far...
# Written 27000000 records so far...
# Written 27100000 records so far...
# Written 27200000 records so far...
# Written 27300000 records so far...
# Written 27400000 records so far...
# Written 27500000 records so far...
# Written 27600000 records so far...
# Written 27700000 records so far...
# Written 27800000 records so far...
# Written 27900000 records so far...
# Written 28000000 records so far...
# Written 28100000 records so far...
# Written 28200000 records so far...
# Written 28300000 records so far...
# Written 28400000 records so far...
# Written 28500000 records so far...
# Written 28600000 records so far...
# Written 28700000 records so far...
# Written 28800000 records so far...
# Written 28900000 records so far...
# Written 29000000 records so far...
# Written 29100000 records so far...
# Written 29200000 records so far...
# Written 29300000 records so far...
# Written 29400000 records so far...
# Written 29500000 records so far...
# Written 29600000 records so far...
# Written 29700000 records so far...
# Written 29800000 records so far...
# Written 29900000 records so far...
# Written 30000000 records so far...
# Dataset 'large_student_scores.csv' with 30000000 records generated successfully.
